# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from cameo.core import manipulation
from cameo import fba, flux_variability_analysis
from cobra.io import read_sbml_model

# %%
from cameo.strain_design.heuristic.evolutionary_based import OptGene
from cobra.io import read_sbml_model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\pauli\OneDrive\Dokumenty\DTU\Cell factories\group-assingment-team11\09_Optgene.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pauli/OneDrive/Dokumenty/DTU/Cell%20factories/group-assingment-team11/09_Optgene.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from cameo.strain_design.heuristic.evolutionary_based import OptGene
#       <a href='vscode-notebook-cell:/c%3A/Users/pauli/OneDrive/Dokumenty/DTU/Cell%20factories/group-assingment-team11/09_Optgene.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> from cobra.io import read_sbml_model
#
# File c:\Users\pauli\anaconda3\Lib\site-packages\cameo\strain_design\__init__.py:18
#      15 from __future__ import absolute_import
#      17 from cameo.strain_design.deterministic import OptKnock, FSEOF, DifferentialFVA
# ---> 18 from cameo.strain_design.heuristic import OptGene
#
# File c:\Users\pauli\anaconda3\Lib\site-packages\cameo\strain_design\heuristic\__init__.py:17
#       1 # Copyright 2014 Novo Nordisk Foundation Center for Biosustainability, DTU.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from __future__ import absolute_import
# ---> 17 from cameo.strain_design.heuristic.evolutionary_based import OptGene
#
# File c:\Users\pauli\anaconda3\Lib\site-packages\cameo\strain_design\heuristic\evolutionary_based.py:38
#      34 from cameo.strain_design.heuristic.evolutionary.objective_functions import biomass_product_coupled_min_yield, \
#      35     biomass_product_coupled_yield
#      36 from cameo.strain_design.heuristic.evolutionary.optimization import GeneKnockoutOptimization, \
#      37     ReactionKnockoutOptimization, CofactorSwapOptimization, NADH_NADPH
# ---> 38 from cameo.strain_design.heuristic.evolutionary.processing import process_reaction_knockout_solution, \
#      39     process_gene_knockout_solution, process_reaction_swap_solution
#      40 from cameo.util import TimeMachine
#      41 from cameo.core.utils import get_reaction_for
#
# File c:\Users\pauli\anaconda3\Lib\site-packages\cameo\strain_design\heuristic\evolutionary\processing.py:14
#       1 # Copyright 2016 Novo Nordisk Foundation Center for Biosustainability, DTU.
#       2
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from cobra.manipulation.delete import find_gene_knockout_reactions
#      15 from cameo.core.manipulation import swap_cofactors
#      17 from cameo import flux_variability_analysis
#
# ImportError: cannot import name 'find_gene_knockout_reactions' from 'cobra.manipulation.delete' (c:\Users\pauli\anaconda3\Lib\site-packages\cobra\manipulation\delete.py)
