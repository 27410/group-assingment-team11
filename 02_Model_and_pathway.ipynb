# %% [markdown]
# ### Model decision

# %%
pip install memote
# Out:
# Checking `git` installation.
# critical: Working with a repository requires a storage location.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !memote run Models/iND750.xml
# Out:
# Checking `git` installation.
# critical: Working with a repository requires a storage location.

# %%
# !memote report diff Models/iFF708.xml Models/iIN800.xml Models/iLL672.xml Models/iMM904.xml Models/iND750.xml Models/yeast8.xml
# Out:
# Writing problem data to 'C:\Users\Pablo\AppData\Local\Temp\tmplbimuhsq.glpk'...
# 15212 lines were written
# Writing problem data to 'C:\Users\Pablo\AppData\Local\Temp\tmpzpcj7hbw.glpk'...
# 20822 lines were written
# Writing problem data to 'C:\Users\Pablo\AppData\Local\Temp\tmpr3377sqg.glpk'...
# 13191 lines were written
# Writing problem data to 'C:\Users\Pablo\AppData\Local\Temp\tmpwqqekf5a.glpk'...
# 20574 lines were written
# Writing problem data to 'C:\Users\Pablo\AppData\Local\Temp\tmp59zzr371.glpk'...
# 16729 lines were written
# Writing problem data to 'C:\Users\Pablo\AppData\Local\Temp\tmpookrkgnv.glpk'...
# 50498 lines were written
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ...
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ...
# ...
# ...
# error: No objective coefficients in model. Unclear what should be optimized
# ...
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ...

# %%
from cobra.io import read_sbml_model

# %%
model = read_sbml_model('Models/yeast8.xml')

# %%
model
# Out:
# <Model yeastGEM_v8__46__7__46__1 at 0x222f85f9f10>

# %% [markdown]
# ### Isoamyl acetate pathway

# %%
from PIL import Image

# Load the image
image = Image.open("Pictures/iso_ace_pathway.jpg")

# Display the image
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=489x612>

# %%
from cobra.io import read_sbml_model
from cobra import Reaction, Metabolite, Model

model = read_sbml_model('Models/yeast8.xml')

# %%
print(model)
# Out:
# yeastGEM_v8__46__7__46__1
